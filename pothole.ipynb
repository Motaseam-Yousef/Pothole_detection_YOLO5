# %% [markdown]
# <a align="left" href="https://ultralytics.com/yolov5" target="_blank">
# <img width="1024", src="https://user-images.githubusercontent.com/26833433/125273437-35b3fc00-e30d-11eb-9079-46f313325424.png"></a>
#
# This is the **official YOLOv5 🚀 notebook** by **Ultralytics**, and is freely available for redistribution under the [GPL-3.0 license](https://choosealicense.com/licenses/gpl-3.0/).
# For more information please visit https://github.com/ultralytics/yolov5 and https://ultralytics.com. Thank you!

# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.1-243-g7cef03d Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.2/78.2 GB disk)

# %%
# unrar the images and the labels, after upload it to the colab
#!pip install patool
#import patoolib
#patoolib.extract_archive("/content/data.rar", outdir="/content/data")

# %%
# Train YOLOv5s on Custom for 3 epochs
# !python train.py --img 640 --batch 16 --epochs 2 --data /content/yolov5/data/custom_data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/yolov5/data/custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=2, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-243-g7cef03d Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 100 --data /content/yolov5/data/custom_data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/yolov5/data/custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-243-g7cef03d Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python detect.py --weights runs/train/exp2/weights/best.pt --img 640 --conf 0.35 --source /content/IT.jpg
# !python detect.py --weights runs/train/exp2/weights/best.pt --img 640 --conf 0.35 --source /content/VT.mp4
# Out:
# detect: weights=['runs/train/exp2/weights/best.pt'], source=/content/IT.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-243-g7cef03d Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/IT.jpg: 640x640 2 potholes, Done. (0.013s)
# Speed: 0.5ms pre-process, 12.9ms inference, 1.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp
# ...

# %%
from google.colab import files

# !zip -r /content.zip /content/
# Out:
# updating: content/ (stored 0%)
# updating: content/.config/ (stored 0%)
# updating: content/.config/configurations/ (stored 0%)
# updating: content/.config/configurations/config_default (deflated 15%)
# updating: content/.config/config_sentinel (stored 0%)
# updating: content/.config/active_config (stored 0%)
# updating: content/.config/.last_opt_in_prompt.yaml (stored 0%)
# updating: content/.config/logs/ (stored 0%)
# updating: content/.config/logs/2022.06.01/ (stored 0%)
# updating: content/.config/logs/2022.06.01/13.49.06.780242.log (deflated 54%)
# updating: content/.config/logs/2022.06.01/13.49.32.423822.log (deflated 54%)
# updating: content/.config/logs/2022.06.01/13.49.51.363739.log (deflated 54%)
# updating: content/.config/logs/2022.06.01/13.49.25.228288.log (deflated 86%)
# updating: content/.config/logs/2022.06.01/13.48.45.927171.log (deflated 91%)
# updating: content/.config/logs/2022.06.01/13.49.52.118738.log (deflated 54%)
# ...
